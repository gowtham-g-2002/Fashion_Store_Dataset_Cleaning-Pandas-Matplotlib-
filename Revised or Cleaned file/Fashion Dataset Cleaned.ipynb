# %%
import pandas as pd

# %%
data = pd.read_csv("FashionDataset.csv")

# %%
data.head()

# %%
data.info()

# %%
data.shape

# %%
data.columns

# %%
data.drop(columns = "Unnamed: 0",inplace = True)

# %%
data.head(1)

# %%
data.columns

# %%
data.rename(columns = {"Deatils" : "Details"},inplace = True)

# %%
data.head(1)

# %%
data.duplicated().value_counts().plot(kind="bar")

# %%
import matplotlib as plt

# %%
data.duplicated().value_counts().plot(kind="pie")
plt.title("Duplicate Rows")
plt.ylabel("")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 data.duplicated().value_counts().plot(kind="pie")
# ----> 2 plt.title("Duplicate Rows")
#       3 plt.ylabel("")
#       4 plt.legend()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
data.duplicated().sum()
# Out:
# np.int64(2827)

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape[0]
# Out:
# 27931

# %%
data
# Out:
#                 BrandName                                            Details  \
# 0                    life  solid cotton blend collar neck womens a-line d...
# 1                    only  polyester peter pan collar womens blouson dres...
# 2                 fratini  solid polyester blend wide neck womens regular...
# 3             zink london  stripes polyester sweetheart neck womens dress...
# 4                    life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 30752  shaya by caratlane               the wing woman clover charm necklace
# 30753           swarovski            crystal stylish womens rodhium earrings
# 30755              jewelz                 ethnic gold plated jhumki earrings
# 30756             estelle  womens gold plated double line fancy white and...
# 30757             estelle  womens gold plated bridge designer mangalsutra...
#
#                                          Sizes       MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                             Size:34,36,38,40  Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36  Rs\n1699       849  50% off
# ...                                        ...       ...       ...      ...
# 30752                                      Nan       Nan      1250      Nan
# 30753                                      Nan       Nan      8950      Nan
# 30755                                      Nan  Rs\n1839       643  65% off
# 30756                                      Nan       Nan      2799      Nan
# 30757                                      Nan       Nan      1899      Nan
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 30752    Jewellery-Women
# 30753    Jewellery-Women
# 30755    Jewellery-Women
# 30756    Jewellery-Women
# 30757    Jewellery-Women
#
# [27931 rows x 7 columns]

# %%
data.reset_index().tail()
# Out:
#        index           BrandName  \
# 27926  30752  shaya by caratlane
# 27927  30753           swarovski
# 27928  30755              jewelz
# 27929  30756             estelle
# 27930  30757             estelle
#
#                                                  Details Sizes       MRP  \
# 27926               the wing woman clover charm necklace   Nan       Nan
# 27927            crystal stylish womens rodhium earrings   Nan       Nan
# 27928                 ethnic gold plated jhumki earrings   Nan  Rs\n1839
# 27929  womens gold plated double line fancy white and...   Nan       Nan
# 27930  womens gold plated bridge designer mangalsutra...   Nan       Nan
#
#       SellPrice Discount         Category
# 27926      1250      Nan  Jewellery-Women
# 27927      8950      Nan  Jewellery-Women
# 27928       643  65% off  Jewellery-Women
# 27929      2799      Nan  Jewellery-Women
# 27930      1899      Nan  Jewellery-Women

# %%
data.reset_index().drop(columns="index")
# Out:
#                 BrandName                                            Details  \
# 0                    life  solid cotton blend collar neck womens a-line d...
# 1                    only  polyester peter pan collar womens blouson dres...
# 2                 fratini  solid polyester blend wide neck womens regular...
# 3             zink london  stripes polyester sweetheart neck womens dress...
# 4                    life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 27926  shaya by caratlane               the wing woman clover charm necklace
# 27927           swarovski            crystal stylish womens rodhium earrings
# 27928              jewelz                 ethnic gold plated jhumki earrings
# 27929             estelle  womens gold plated double line fancy white and...
# 27930             estelle  womens gold plated bridge designer mangalsutra...
#
#                                          Sizes       MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                             Size:34,36,38,40  Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36  Rs\n1699       849  50% off
# ...                                        ...       ...       ...      ...
# 27926                                      Nan       Nan      1250      Nan
# 27927                                      Nan       Nan      8950      Nan
# 27928                                      Nan  Rs\n1839       643  65% off
# 27929                                      Nan       Nan      2799      Nan
# 27930                                      Nan       Nan      1899      Nan
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 27926    Jewellery-Women
# 27927    Jewellery-Women
# 27928    Jewellery-Women
# 27929    Jewellery-Women
# 27930    Jewellery-Women
#
# [27931 rows x 7 columns]

# %%
data.isna().sum()
# Out:
# BrandName    0
# Details      0
# Sizes        0
# MRP          0
# SellPrice    0
# Discount     0
# Category     0
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data["BrandName"] = data["BrandName"].apply(lambda x : x.capitalize())

# %%
data
# Out:
#                 BrandName                                            Details  \
# 0                    Life  solid cotton blend collar neck womens a-line d...
# 1                    Only  polyester peter pan collar womens blouson dres...
# 2                 Fratini  solid polyester blend wide neck womens regular...
# 3             Zink london  stripes polyester sweetheart neck womens dress...
# 4                    Life  regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 30752  Shaya by caratlane               the wing woman clover charm necklace
# 30753           Swarovski            crystal stylish womens rodhium earrings
# 30755              Jewelz                 ethnic gold plated jhumki earrings
# 30756             Estelle  womens gold plated double line fancy white and...
# 30757             Estelle  womens gold plated bridge designer mangalsutra...
#
#                                          Sizes       MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                             Size:34,36,38,40  Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36  Rs\n1699       849  50% off
# ...                                        ...       ...       ...      ...
# 30752                                      Nan       Nan      1250      Nan
# 30753                                      Nan       Nan      8950      Nan
# 30755                                      Nan  Rs\n1839       643  65% off
# 30756                                      Nan       Nan      2799      Nan
# 30757                                      Nan       Nan      1899      Nan
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 30752    Jewellery-Women
# 30753    Jewellery-Women
# 30755    Jewellery-Women
# 30756    Jewellery-Women
# 30757    Jewellery-Women
#
# [27931 rows x 7 columns]

# %%
data["Details"] = data["Details"].apply(lambda x : x.capitalize())

# %%
data
# Out:
#                 BrandName                                            Details  \
# 0                    Life  Solid cotton blend collar neck womens a-line d...
# 1                    Only  Polyester peter pan collar womens blouson dres...
# 2                 Fratini  Solid polyester blend wide neck womens regular...
# 3             Zink london  Stripes polyester sweetheart neck womens dress...
# 4                    Life  Regular fit regular length denim womens jeans ...
# ...                   ...                                                ...
# 30752  Shaya by caratlane               The wing woman clover charm necklace
# 30753           Swarovski            Crystal stylish womens rodhium earrings
# 30755              Jewelz                 Ethnic gold plated jhumki earrings
# 30756             Estelle  Womens gold plated double line fancy white and...
# 30757             Estelle  Womens gold plated bridge designer mangalsutra...
#
#                                          Sizes       MRP SellPrice Discount  \
# 0      Size:Large,Medium,Small,X-Large,X-Small  Rs\n1699       849  50% off
# 1                             Size:34,36,38,40  Rs\n3499      2449  30% off
# 2                  Size:Large,X-Large,XX-Large  Rs\n1199       599  50% off
# 3              Size:Large,Medium,Small,X-Large  Rs\n2299      1379  40% off
# 4                       Size:26,28,30,32,34,36  Rs\n1699       849  50% off
# ...                                        ...       ...       ...      ...
# 30752                                      Nan       Nan      1250      Nan
# 30753                                      Nan       Nan      8950      Nan
# 30755                                      Nan  Rs\n1839       643  65% off
# 30756                                      Nan       Nan      2799      Nan
# 30757                                      Nan       Nan      1899      Nan
#
#                 Category
# 0      Westernwear-Women
# 1      Westernwear-Women
# 2      Westernwear-Women
# 3      Westernwear-Women
# 4      Westernwear-Women
# ...                  ...
# 30752    Jewellery-Women
# 30753    Jewellery-Women
# 30755    Jewellery-Women
# 30756    Jewellery-Women
# 30757    Jewellery-Women
#
# [27931 rows x 7 columns]

# %%
type(data["Sizes"][27929])
# Out:
# str

# %%
data['Sizes'] = data['Sizes'].replace('Nan','NA VALUED')

# %%
data = data[data['Sizes'] != 'NA VALUED']

# %%
data['Discount'] = data['Discount'].replace('Nan', 'NO DISCOUNT')
# Out:
# C:\Users\rgbro\AppData\Local\Temp\ipykernel_13384\3547051243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Discount'] = data['Discount'].replace('Nan', 'NO DISCOUNT')

# %%
data['Discount']
# Out:
# 0            50% off
# 1            30% off
# 2            50% off
# 3            40% off
# 4            50% off
#             ...
# 26885        70% off
# 27290        33% off
# 28418        33% off
# 28664    NO DISCOUNT
# 28716    NO DISCOUNT
# Name: Discount, Length: 22687, dtype: object

# %%
data
# Out:
#             BrandName                                            Details  \
# 0                Life  Solid cotton blend collar neck womens a-line d...
# 1                Only  Polyester peter pan collar womens blouson dres...
# 2             Fratini  Solid polyester blend wide neck womens regular...
# 3         Zink london  Stripes polyester sweetheart neck womens dress...
# 4                Life  Regular fit regular length denim womens jeans ...
# ...               ...                                                ...
# 26885     Swiss eagle                     Womens analogue metallic watch
# 27290  Lawman watches  Womens rose gold dial stainless steel analogue...
# 28418  Lawman watches  Womens silver dial stainless steel analogue wa...
# 28664         Miu miu                              Eau de parfum - 50 ml
# 28716         Miu miu                              Eau de parfum - 30 ml
#
#                                          Sizes        MRP SellPrice  \
# 0      Size:Large,Medium,Small,X-Large,X-Small   Rs\n1699       849
# 1                             Size:34,36,38,40   Rs\n3499      2449
# 2                  Size:Large,X-Large,XX-Large   Rs\n1199       599
# 3              Size:Large,Medium,Small,X-Large   Rs\n2299      1379
# 4                       Size:26,28,30,32,34,36   Rs\n1699       849
# ...                                        ...        ...       ...
# 26885                          Size:Error Size  Rs\n13990      4197
# 27290                          Size:Error Size   Rs\n7499      4999
# 28418                          Size:Error Size   Rs\n5999      3999
# 28664                          Size:Error Size        Nan      6100
# 28716                          Size:Error Size        Nan      4400
#
#           Discount           Category
# 0          50% off  Westernwear-Women
# 1          30% off  Westernwear-Women
# 2          50% off  Westernwear-Women
# 3          40% off  Westernwear-Women
# 4          50% off  Westernwear-Women
# ...            ...                ...
# 26885      70% off      Watches-Women
# 27290      33% off      Watches-Women
# 28418      33% off      Watches-Women
# 28664  NO DISCOUNT    Fragrance-Women
# 28716  NO DISCOUNT    Fragrance-Women
#
# [22687 rows x 7 columns]

# %%
data = data.reset_index().drop(columns = "index")

# %%
data.to_excel("Cleaned_Fashion_dataset.xlsx",index = False)
